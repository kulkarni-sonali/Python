# %%
# Assignment 2

#Determine the type of triangle based on side lengths -equilateral, isosceles, scalene 

a=int(input("Enter the first side :"))
b=int(input("Enter the second side:"))
c=int(input("Enter the third side:"))

if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("Equilateral Triangle")
    elif a==b or b==c or a==c:
        print("Isosceles Triangle")
    else:
        print("Scelene Triangle")
else:
    print("Not a valid Triangle")
# Out:
# Scelene Triangle

# %%
#write a program to determine the category of given price: low (less than 100), medium (100-500), high (501-1000), very high (above1000)

price=int(input("Enter the Price: "))

if price<100:
    category="Low"
elif 100<= price<=500:
    category="Medium"
elif 501<= price <=1000:
    category="High"
else:
    category="Very High"

print("Price Category:", category)
# Out:
# Price Category: High

# %%
# BMI Calculator

height=int(input("Enter your height in cm: "))
weight=int(input("Enter your weight in kg: "))

bmi= weight/(height/100)**2
if bmi<18.5:
    print(f"Your BMI is {bmi}, you are underweight.")   
elif 18.5<=bmi<=24.9:
    print(f"Your BMI is {bmi}, you have a normal weight.")  
elif 25<=bmi<=29.9:
    print(f"Your BMI is {bmi}, you are overweight.")
else:
    print(f"Your BMI is {bmi}, you are obese.")
# Out:
# Your BMI is 24.121749046094468, you have a normal weight.

# %%
# ATM Simulation ( Check balance, withdraw money, deposit money, exit)
balance=1000000
while True:
    print("\nWelcome to the ATM")
    print("1. Check Balance")
    print("2. Withdraw Money")
    print("3. Deposit Money")
    print("4. Exit")
    
    choice=int(input("Enter your choice (1-4): "))
    
    if choice==1:
        print(f"Your current balance is: ${balance}")
    elif choice==2:
        amount=int(input("Enter amount to withdraw: "))
        if amount>balance:
            print("Insufficient balance!")
        else:
            balance-=amount
            print(f"${amount} withdrawn successfully. New balance: ${balance}")
    elif choice==3:
        amount=int(input("Enter amount to deposit: "))
        balance+=amount
        print(f"${amount} deposited successfully. New balance: ${balance}")
    elif choice==4:
        print("Thank you for using the ATM. Goodbye!")
        break
    else:
        print("Invalid choice! Please try again.")
# Out:
# Welcome to the ATM
# 1. Check Balance
# 2. Withdraw Money
# 3. Deposit Money
# 4. Exit
# $2000 withdrawn successfully. New balance: $998000
#
# Welcome to the ATM
# 1. Check Balance
# 2. Withdraw Money
# 3. Deposit Money
# 4. Exit
# Your current balance is: $998000
#
# Welcome to the ATM
# 1. Check Balance
# 2. Withdraw Money
# 3. Deposit Money
# 4. Exit
# $2000 withdrawn successfully. New balance: $996000
#
# Welcome to the ATM
# 1. Check Balance
# 2. Withdraw Money
# 3. Deposit Money
# 4. Exit
# Thank you for using the ATM. Goodbye!

# %%
balance = 1000
while True:
    print("2. Withdrawl")
    print("1. Balance")
    print("3. Deposit")

    choice = int(input("Enter your choice"))

    if choice == 1:
        print("Your current balance is:",balance)
    elif choice == 2:
        amount = int(input("Enter the amount: "))
        if amount>0 and amount<=balance:
            balance -= amount
            print("Your current balace is:",balance)
        else:
            print("Enter valid Amount")
    elif choice == 3:
        amount = int(input("Enter the amount: "))
        if amount>0:
            balance += amount
            print("Your current balace is:",balance)
        else:
            print("Enter valid Amount")
    else:
        print("Enter valid option")
# Out:
# 2. Withdrawl
# 1. Balance
# 3. Deposit
# Your current balance is: 1000
# 2. Withdrawl
# 1. Balance
# 3. Deposit
# Your current balace is: 800
# 2. Withdrawl
# 1. Balance
# 3. Deposit
# Your current balace is: 600
# 2. Withdrawl
# 1. Balance
# 3. Deposit
# Your current balance is: 600
# 2. Withdrawl
# 1. Balance
# 3. Deposit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 7
#       4 print("1. Balance")
#       5 print("3. Deposit")
# ----> 7 choice = int(input("Enter your choice"))
#       9 if choice == 1:
#      10     print("Your current balance is:",balance)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#determine the day of the week based on given number( 1-7)

day=int(input("Enter a number (1-7) to get the corresponding day of the week: "))   
if day==1:
    print("Monday")         
elif day==2:
    print("Tuesday")            
elif day==3:
    print("Wednesday")
elif day==4:
    print("Thursday")
elif day==5:
    print("Friday")
elif day==6:        
    print("Saturday")
elif day==7:
    print("Sunday")

else:
    print("Invalid input! Please enter a number between 1 and 7.")

# Check if a year is a leap year or not
year=int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# Saturday
