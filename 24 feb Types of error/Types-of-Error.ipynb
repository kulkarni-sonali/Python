# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Denomenator is Zero")
# Out:
# Denomenator is Zero

# %%
try:
    prin("Hello")
except NameError:
    print("Something Incomplete")
# Out:
# Something Incomplete

# %%
try:
    def my_function():
    print("Not indented")
except IndentationError:
    print("No Indentation")
# Out:
#   Cell In[11], line 2
#     def my_function():
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1

# %%
# SyntaxError: invalid syntax (missing colon)

try:
    if True
        print("Missing colon")
except SyntaxError:
    print("Error")
finally:
    print("Error")
# Out:
#   Cell In[14], line 4
#     if True
#            ^
# SyntaxError: expected ':'

# %%
print(unknown_variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(unknown_variable)
#
# NameError: name 'unknown_variable' is not defined

# %%
result = "Score: " + 10  # Cannot add string and int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = "Score: " + 10  # Cannot add string and int
#
# TypeError: can only concatenate str (not "int") to str

# %%
items = [1, 2, 3]
print(items[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 items = [1, 2, 3]
# ----> 2 print(items[5])
#
# IndexError: list index out of range

# %%
user = {"name": "Alice"}
print(user["age"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 user = {"name": "Alice"}
# ----> 2 print(user["age"])
#
# KeyError: 'age'

# %%
number = int("abc")  # "abc" cannot be an integer
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 number = int("abc")  # "abc" cannot be an integer
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
text = "hello"
text.append("world")  # Strings don't have .append()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 text = "hello"
# ----> 2 text.append("world")  # Strings don't have .append()
#
# AttributeError: 'str' object has no attribute 'append'

# %%
code_to_check = """
if True
    print("Missing colon")
"""

try:
    exec(code_to_check)
except SyntaxError as e:
    print(f"Caught a SyntaxError: {e}")
finally:
    print("Validation complete.")
# Out:
# Caught a SyntaxError: expected ':' (<string>, line 2)
# Validation complete.

# %%
code_to_check="""
try:
    def my_function():
    print("Not indented")
except IndentationError:
    print("No Indentation")
"""

try:
    exec(code_to_check)
except IndentationError as i:
    print(f"Caught the Error {i}")
finally:
    print("Vslidation complete")
# Out:
# Caught the Error expected an indented block after function definition on line 3 (<string>, line 4)
# Vslidation complete
