# %%
try:
    f=open("data.txt","r")
    data =f.read()
    print(data)
    f.close()
except FileNotFoundError:
    print("File Not Found")


print(2+2)
# Out:
# File Not Found
# 4

# %%
try:
    a=5
    b=0

    print(a/b)
except ZeroDivisionError:
    print("Denominator is Zero")
# Out:
# Denominator is Zero

# %%
try:
    x = 10 / 0
    print(a/b)
except ZeroDivisionError:
    print("ZeroDivisionError, Denominator is Zero")
# Out:
# ZeroDivisionError, Denominator is Zero

# %%
try:
    
    print("Hello"
except SyntaxError:
    print("'(' was never closed")
# Out:
#   Cell In[8], line 3
#     print("Hello"
#          ^
# SyntaxError: '(' was never closed

# %%
try:
    exec('print("Hello"')   # incomplete input
except SyntaxError as e:
    print("SyntaxError caught:", e)
# Out:
# SyntaxError caught: '(' was never closed (<string>, line 1)

# %%
try:
    code = 'def my_function():\nprint("Not indented")'
    exec(code)
except IndentationError as e:
    print("Indentation Error caught:", e)
# Out:
# Indentation Error caught: expected an indented block after function definition on line 1 (<string>, line 2)

# %%
try:
    if True
    print("Missing colon")

except SyntaxError:
    print("Syntax error occured, :is missing ")
# Out:
#   Cell In[10], line 2
#     if True
#            ^
# SyntaxError: expected ':'

# %%
#try:  
#    print ( unknown variable)
#except NameError:
 #   print( Name error occured)

try:
    print(unknown_variable) # Code that might raise a NameError
except NameError:
    print("Name error occurred: The variable is not defined") # Code to run if NameError occurs
# Out:
# Name error occurred: The variable is not defined

# %%
code_with_error = """
def my_function():
print("Not indented")
"""

try:
    exec(code_with_error)
except IndentationError:
    print("Caught an IndentationError from the string input!")
# Out:
# Caught an IndentationError from the string input!

# %%
#code with KeyError
#result = "Score: " + 10  # Cannot add string and int

try:
    result = "Score: " + 10
except TypeError as e:
    print(f"TypeError occured :{e}")
# Out:
# TypeError occured :can only concatenate str (not "int") to str

# %%
#code with Error
# items = [1, 2, 3]
# print(items[5])


try:
    items =[1,2,3]
    print (items[5])
except IndexError as e:
    print(f"caught IndexError as: {e}")
# Out:
# caught IndexError as: list index out of range

# %%
#code with Error
# user = {"name": "Alice"}
# print(user["age"])

try:
    user ={"name": "Alice"}
    print(user["age"])
except KeyError as e:
    print( f"caught keyerror as:{e}")
# Out:
# caught keyerror as:'age'

# %%
# Code wit error
# number = int("abc")  # "abc" cannot be an integer

try:
    number = int("abc")
except ValueError as e:
    print(f"caught value error as :{e}")
# Out:
# caught value error as :invalid literal for int() with base 10: 'abc'

# %%
# code wit error
#text = "hello"
#text.append("world")  # Strings don't have .append()

try:
    text = "hello"
    text.append("world")  # Strings don't have .append()

except AttributeError as e:
    print(f"caught AtributeError as :{e}")
# Out:
# caught AtributeError as :'str' object has no attribute 'append'

# %%
# code with error
#if True
#    print("Missing colon")



code_to_check ="""
if True
    print("Missing colon")
"""

try:
    exec(code_to_check)
except SyntaxError as e:
    print(f"Caught a SyntaxError: {e}")
finally:
    print("Validation complete.")
# Out:
# Caught a SyntaxError: expected ':' (<string>, line 2)
# Validation complete.

# %%
# Code wit error

 #def my_function():
  #  print("Not indented")

code_to_check="""
try:
    def my_function():
    print("Not indented")
except IndentationError:
    print("No Indentation")
"""

try:
    exec(code_to_check)
except IndentationError as i:
    print(f"Caught the Error {i}")
finally:
    print("Vslidation complete")
