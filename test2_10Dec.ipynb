# %%
for i in range(3):
    i += 1
print(i)
# Out:
# 3

# %%
sum = 0
for x in range(1, 5, 2):
    sum += x
print(sum)
# Out:
# 4

# %%
for i in "123":
    i = int(i) + 1
print(i)
# Out:
# 4

# %%
age = "30"
print(age)
print(type(age))
age = int("30")
print(age)
print(type(age))
# Out:
# 30
# <class 'str'>
# 30
# <class 'int'>

# %%
for i in range(3):
    pass
print(i)
# Out:
# 2

# %%
i = 5
while i > 0:
    i -= 2
print("Done")
# Out:
# Done

# %%
i = 0
while i < 5:
    print(i)
    i = i + i
    if i == 0:
        i = 1
# Out:
# 0
# 1
# 2
# 4

# %%
s = "sonali"
print(s.count("an"))
# Out:
# 0

# %%
s = "python"
print(s[::2])
# Out:
# pto

# %%
s = "HELLO"
print(s.lower().replace("l","*"))
# Out:
# he**o
