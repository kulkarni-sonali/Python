# %%
for i in range(5,-4,-2): # range is in between 5 to -4, i.e. output will be till -3, but last digit in the range is -2 that means from 5 2 int wil be skipped

    print(i, end=" ")

    

if True:
    print("Hello")
else:
    print("Bye")
# Out:
# 5 3 1 -1 -3 Hello

# %%
x = 10
if x <10 or x == 10:    # if we use || sign instead of 'or' then it will give error. as this sign is used in C, C++, Java language
    print(f"{x} is less than or equal to 10")   # without f before {x} will print output as {x} but with f out will be value of {x}
else:
    print(f"{x} is greater than10")
# Out:
# 10 is less than or equal to 10

# %%
s = 'hi!'
for i in range(len(s) -1,-1,-1):
    print (s[i]*2, end ="")     #space in between " " will decide space between characters in output
# Out:
# !!iihh

# %%
n = 10
while True:
    n +=1
    if n%2 ==0:
        continue
    if n >=20:
        break
    print(n, end = " ")
# Out:
# 11 13 15 17 19

# %%
alpha1 = ord("""#""")
alpha2 = ord('''A''')

print(f" Addition of {chr(alpha1)}", end="")
print(f"and {chr(alpha2)} is {alpha1+alpha2}")
# Out:
#  Addition of #and A is 100

# %%
for i in range(1,11,1):
    pass
print(i)
# Out:
# 10

# %%
i = 1
while i<=10:
    if i % 2 == 0:
        print(i)
    i+=1
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
i = 1
while i<11:
    pass
    i+=1
print(i -1)
# Out:
# 10
