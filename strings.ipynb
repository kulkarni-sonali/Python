# %%
name = "Sonali Kulkarni"

print(name)
# Out:
# Sonali Kulkarni

# %%
print(name[14])
print(name[-15])
print(name[-1])
# Out:
# i
# S
# i

# %%
print(name[0:6])
# Out:
# Sonali

# %%
first_name = "Sonale"

print(first_name)

first_name[5] = "i"

print(first_name)
# Out:
# Sonale
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 first_name = "Sonale"
#       3 print(first_name)
# ----> 5 first_name[5] = "i"
#       7 print(first_name)
#
# TypeError: 'str' object does not support item assignment

# %%
first_name = "Sonale"

print(first_name)
print(id(first_name))

first_name = "Sonali"

print(first_name)
print(id(first_name))

# %%
l = ["Sonale", 14, 66.78, True]

print(l)
print(id(l))

l[0] = "Sonali"

print(l)
print(id(l))

# %%
name1 = "Dhananjay"
name2 = "Dhananjay"

print(name1)
print(id(name1))

print(name2)
print(id(name2))

# %%
msg = "Hello"

print(msg[0])       # prints H
print(msg[4])       # prints o
print(msg[-0])      # prints H, -0 is same as 0
print(msg[-1])      # prints o
print(msg[-2])      # prints l
print(msg[-5])      # prints H
print(msg[-6])      # Index error: string index out of range

# %%
# A substring can be sliced out of a string

# 1 s[start : end] -extract from start to end -1
print(msg[0:5])

# 2 s[start :] - extract from start to end
print(msg[1:])

# 3 s[: end] - extract from start to end -1
print(msg[0:100])

# 4 s[-start :] - extract from - start(included) to end
print(msg[-5:])

# 5 s[:-end] - extract from begining to -end-1
print(msg[:-2]) # being -2, expression stopped at -3

# %%
# STRING PROPERTIES

# 1. Python strings are immutable - they can not be changed

message="Hello"
message[0]="M" # Rejected attempt to mutate (change) string

message = "Hii.."
print(message[0])

# %%
# strings can be concatenated by using +

name="Arjun"
sur_name="Diwedi"

print(name + sur_name)

# strings can be replicated during printing

print("-" * 50)     #prints ---------

#whether on estring is part of another can be found out using (in)

print("e" in "Hello")       # prints True
print("z" in "Hello")       # prints False
print("lo" in "Hello")      # prints True

# %%
# BUILT IN FUNCTION # ASCCI TABLE

# 1. len(): returns the length of the string, which is the number of characters in the string.

my_string = "Hello, World!"
print(len(my_string))

message = "Racer car 0.1"
print(len(message))

# 2. max(): Returns the character with the highest unicode value ( Referring ASCCI Table) int the string.

my_string = "hello, World!"
print(max(my_string))

passcode = "Unicornx; @ ?!"
print(max(passcode))

# 3. min(): Returns the character with the lowest unicode value ( Referring ASCCI Table) int the string.

my_string = "Hello World!"  # here output would be  space i.e. " " as it has minimum ASCCI value
print(min(my_string))

passcode = "Unicornx; @ ?!" # here output would be  space i.e. " " as it has minimum ASCCI value
print(min(passcode))
# Out:
# 13
# 13
# r
# x

# %%
str1 = "Hello"
str2 = "Hello123"

print(str1.isalpha())
print(str2.isalpha())
# Out:
# True
# False

# %%
str1 = "123"
str2 = "123abc"
print(str1.isdigit())
print(str2.isdigit())
# Out:
# True
# False

# %%
str1 = "Hello123"
str2 = "Hello@123"
print(str1.isalnum())
print(str2.isalnum())
# Out:
# True
# False

# %%
str1 = "HELLO"
str2 = "Hello"

print(str1.isupper())
print(str2.isupper())
print(str1.lower().replace("h","s") )
# print(s.lower().replace("l","*"))
# Out:
# True
# False
# sello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       5 print(str2.isupper())
#       6 print(str1.lower().replace("h","s") )
# ----> 7 print(s.lower().replace("l","*"))
#
# NameError: name 's' is not defined

# %%
str1 = "hello"
str2 = "Hello"

print(str1.islower())
print(str2.islower())
# Out:
# True
# False

# %%
my_string = "Hello, world!"

print(my_string.startswith("Hello"))
print(my_string.startswith("World"))
# Out:
# True
# False

# %%
my_string = "Hello, World!"

print(my_string.endswith("World!"))
print(my_string.endswith("hello"))
# Out:
# True
# False

# %%
sentence = "Hello, how are you?"
index = sentence.find("how")
print(index)        # output will be index of place of start of word i.e. h in how
print(sentence.find("how"))# the print order or output order can also be written like this
# Out:
# 7
# 7

# %%
sentence = "Hello, how are you?"
index1 = id(sentence)
print(index1)

print(sentence.replace("how" , "where"))

sentence = sentence.replace("how", "where")
index2 = id(sentence)
print(index2)

print(sentence)
# Out:
# 2255235923760
# Hello, where are you?
# 2255235922352
# Hello, where are you?

# %%
text="\thello, how are you?"
print(text)
print(text.lstrip())
# Out:
# 	hello, how are you?
# hello, how are you?

# %%
text="hello, how are you?\t"
print(text)
print(text.rstrip())
# Out:
# hello, how are you?
# hello, how are you?

# %%
text = "\tHello, How are you?\t"
print(text)
print(text.strip())
# Out:
# 	Hello, How are you?

# %%
# SPLIT PARTITION JOIN
#1

sentence= "How are you?"

words = sentence.split(" ")

print(words)
print(type(words))

#2

Text = "apple, banana, orange"

Fruits=Text.split(",")

print(Fruits)
print(type(Fruits))

#3

Text = "apple, banana, orange"
ffruits,sfruits,tfruits=Text.split(",")

print(ffruits,sfruits,tfruits)

print(type(ffruits))
print(type(sfruits))
print(type(tfruits))


#4

name="Arjun Diwedi"
first,last=name.split(" ")

print(f"Hello,{first}")
print(f"{last} is your surname")
# Out:
# ['How', 'are', 'you?']
# <class 'list'>
# ['apple', ' banana', ' orange']
# <class 'list'>
# apple  banana  orange
# <class 'str'>
# <class 'str'>
# <class 'str'>
# Hello,Arjun
# Diwedi is your surname

# %%
# STRING CONVERSION

#1 UPPER CASE

Text="hello world"

Text = Text.upper()
print(Text)


#2 lower case

Text="HELLO WORLD"
Text=Text.lower()
print(Text)


#3 CAPITALIZATION - FIrst letter only

name="arjun"

name=name.capitalize()
print(f"Hello, {name}")


#4 TITLE capitalization of first letter of each word

name=input("What is nyour name ?")
name=name.title()
print(f"Hello,{name}")

#5 Converting   upper character to lower and vice a versa
org_str = "Hello, World"
new_str = org_str.swapcase()
print(new_str)
# Out:
# HELLO WORLD
# hello world
# Hello, Arjun
# Hello,Sonali K
# hELLO, wORLD

# %%
# STRING COMPARISON

s1="Bombay"
s2="bombay"
s3="Nagpur"
s4="Bombaywala"
s5="Bombay"
s6="Mumbai"

print(s1==s2)
print(s2==s3)
print(s1==s5)
print(s1==s6)
print(s1!=s3)
print(s1>s5)
print(s1<s2)
print(s1<=s4)
print(s1<=s6)
# Out:
# False
# False
# True
# False
# True
# False
# True
# True
# True

# %%
string1="INDIA"
index1=id(string1)
print(index1)
print(id(string1))

string2="INDIA"
index2=id(string2)
print(index2)
print(id(string2))

string3="Sonali"
index3=id(string3)
print(index3)
print(id(string3))
# Out:
# 2243405287264
# 2243405287264
# 2243405287264
# 2243405287264
# 2243405529952
# 2243405529952
