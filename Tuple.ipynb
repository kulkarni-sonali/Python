# %% [markdown]
# <h1>Tuple<h1>

# %%
t = ("Sonali", 99.99, True, 12)

t[1] = 100

print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 t = ("Sonali", 99.99, True, 12)
# ----> 3 t[1] = 100
#       5 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
l = ["Sonali", 99.99, True, 12]

l[1] = 100

print(l)
# Out:
# ['Sonali', 100, True, 12]

# %%
a = ()

print(type(a))


b = ("ABC",)

print(type(b))
# Out:
# <class 'tuple'>
# <class 'tuple'>
