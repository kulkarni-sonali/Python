# %%
#Lambda Function

# %%
def SquareIt(n):
    return n*n

n=int(input("Enter the Number to find the sqaure: "   ))
print(f"The Square of {n} is {SquareIt(n)}")

print("\n...........................")

SquareIt = lambda n: n*n

val=int(input("Enter the Number to find the sqaure: "   ))
print(f"\nThe Square of {val} is {SquareIt(val)}")
# Out:
# The Square of 3 is 9
#
# ...........................
#
# The Square of 3 is 9

# %%
# 1. lambda function to find square of given number

SquareIt = lambda n: n*n

val=int(input("Enter the Number to find the sqaure: "   ))
print(f"The Square of {val} is {SquareIt(val)}")
# Out:
# The Square of 5 is 25

# %%
# 2 Lambda function to find sum of 2 given numbers

SumIt=lambda a,b: a+b
val1=int(input("Enter a number: "))
val2= int(input("Enter another number "))

print(f"The sum of {val1} and {val2} is {SumIt(val1, val2)}")
# Out:
# The sum of 3 and 8 is 11

# %%
#IIFE ( UNDER LAMBDA FUNCTIONS)
# IMMEDIATELY INVOKED FUNCTION EXPRESSION 
# CAN NOT TAKE INPUT FROM USER

# %%
print((lambda X: X*2) (12))
# Out:
# 24

# %%
#one parameter one argument only 

print((lambda X: X*2))
# Out:
# <function <lambda> at 0x0000021B36F1A820>

# %%
#one parameter one argument only 

print((lambda X: X*2) (12,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 #one parameter one argument only
# ----> 3 print((lambda X: X*2) (12,2))
#
# TypeError: <lambda>() takes 1 positional argument but 2 were given

# %%
# Using two parameters and one expression

print((lambda x,y:x*y) (12,2))
# Out:
# 24

# %%
# Lambda function can have only one expression

print((lambda x,y: x*2, y*2) (12,2))
# Out:
# <>:3: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# C:\Users\Sonali\AppData\Local\Temp\ipykernel_9508\2634102488.py:3: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
#   print((lambda x,y: x*2, y*2) (12,2))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Lambda function can have only one expression
# ----> 3 print((lambda x,y: x*2, y*2) (12,2))
#
# NameError: name 'y' is not defined

# %%
# Two parameters and one argument

print((lambda x,y: x*y) (12))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Two parameters and one argument
# ----> 3 print((lambda x,y: x*y) (12))
#
# TypeError: <lambda>() missing 1 required positional argument: 'y'

# %%
# Difference between lambda function and UDF (User defined function)
# 1

# User Defined Function
def Reciprocal(num):
    return 1/num

# Lambda function definition
Lambda_Reciprocal = lambda num : 1/num

# Taking input from user
val=int(input("Enter the value to find out reciprocal: "))

# Using the function defined by def keyword
print("\n Usinf UDF:", Reciprocal (val))

# Using teh functiin defind by lambda keyword
print("\n Using lambda function: ", Lambda_Reciprocal(val))
# Out:
#  Usinf UDF: 0.5
#
#  Using lambda function:  0.5

# %%
#2 Even Numbers

list_1=[1,2,3,4,5,6,8,9]
even=list(filter(lambda X: X % 2 == 0, list_1))
print(even)
# Out:
# [2, 4, 6, 8]

# %%
#3 Odd Numbers

list_2= [1,2,3,4,5,6,8,9]
list_odd = list(filter(lambda x: x%2==1, list_2))
print(list_odd)
# Out:
# [1, 3, 5, 9]
